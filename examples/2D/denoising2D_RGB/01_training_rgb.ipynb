# %% [markdown]
# # Noise2Void - 2D Example for RGB Data

# %%
# We import all our dependencies.
from n2v.models import N2VConfig, N2V
import numpy as np
from csbdeep.utils import plot_history
from n2v.utils.n2v_utils import manipulate_val_data
from n2v.internals.N2V_DataGenerator import N2V_DataGenerator
from matplotlib import pyplot as plt
import urllib
import os
import zipfile
# Out:
# Using TensorFlow backend.

# %%
os.environ["CUDA_VISIBLE_DEVICES"]='1'

# %% [markdown]
# # Download Example Data
# Original clean photograph is by Eric Fredericks published on Flickr under CC license: https://creativecommons.org/licenses/by-sa/2.0/.
# Our modified noisy version is under the same license.

# %%
# create a folder for our data
if not os.path.isdir('./data'):
    os.mkdir('data')

# check if data has been downloaded already
zipPath="data/RGB.zip"
if not os.path.exists(zipPath):
    #download and unzip data
    data = urllib.request.urlretrieve('https://cloud.mpi-cbg.de/index.php/s/Frru2hsjjAljpfW/download', zipPath)
    with zipfile.ZipFile(zipPath, 'r') as zip_ref:
        zip_ref.extractall("data")

# %% [markdown]
# # Training Data Preparation
# For training, we will load __one__ low-SNR RGB image and use the <code>N2V_DataGenerator</code> to extract non-overlapping patches.

# %%
# We create our DataGenerator-object.
# It will help us load data and extract patches for training and validation.
datagen = N2V_DataGenerator()

# %%
from skimage import img_as_float32 as img_as_float
import cv2
from skimage.util import random_noise

# %%
# parameter setting

# %%
sigma = 25/255.
patch_size = 32 # should be smaller
batch_size = 64 
epochs = 500
n2v_neighborhood_radius = 2 # 2 in BSD68 dataset ; 5 in bigger one image testing

# %%
img = img_as_float(cv2.imread('/data/image/denoise/test/gt/Set5/woman_GT.bmp', 1)[:, :, ::-1])
img = random_noise(img, mode='gaussian', var=sigma**2, seed=0)
img = np.expand_dims(img, axis=0)
imgs= [img]

# %%
print('shape without alpha:    ',imgs[0].shape)
# Out:
# shape without alpha:     (1, 344, 228, 3)

# %%
# # We will load all the '.png' files from the 'data' directory. In our case it is only one.
# # The function will return a list of images (numpy arrays).
# # In the 'dims' parameter we specify the order of dimensions in the image files we are reading:
# # 'C' stands for channels (color)
# imgs = datagen.load_imgs_from_directory(directory="data/", filter='*.png', dims='YXC')

# # Let's look at the shape of the image
# print('shape of loaded images: ',imgs[0].shape)
# # The function automatically added an extra dimension to the image.
# # It is used to hold a potential stack of images, such as a movie.
# # The image has four color channels (stored in the last dimension): RGB and Aplha.
# # We are not interested in Alpha and will get rid of it.
# imgs[0] = imgs[0][...,:3]
# print('shape without alpha:    ',imgs[0].shape)

# %%
# Let's look at the image.
# We have to remove the added extra dimension to display it as 2D image.
plt.figure(figsize=(32,16))
plt.imshow(imgs[0][0,:,:,...])
plt.show()

# %%
# Next we extract patches for training and validation.
# The parameter 'shape' defines the size of these patches.
patches = datagen.generate_patches_from_list(imgs, shape=(patch_size,patch_size))
# Out:
# Generated patches: (560, 32, 32, 3)

# %%
# Patches are created so they do not overlap.
# (Note: this is not the case if you specify a number of patches. See the docstring for details!)
# Non-overlapping patches enable us to split them into a training and validation set.

nums = patches.shape[0]
# X = patches[:int(0.8*nums)]
X = patches
X_val = patches[int(0.8*nums):]

# %%
# Just in case you don't know how to access the docstring of a method:
datagen.generate_patches_from_list?
# Out:
# Signature:
# datagen.generate_patches_from_list(
#     data,
#     num_patches_per_img=None,
#     shape=(256, 256),
#     augment=True,
#     shuffle=False,
# )
# Docstring:
# Extracts patches from 'list_data', which is a list of images, and returns them in a 'numpy-array'. The images
# can have different dimensionality.
#
# Parameters
# ----------
# data                : list(array(float))
#                       List of images with dimensions 'SZYXC' or 'SYXC'
# num_patches_per_img : int, optional(default=None)
#                       Number of patches to extract per image. If 'None', as many patches as fit i nto the
#                       dimensions are extracted.
# shape               : tuple(int), optional(default=(256, 256))
#                       Shape of the extracted patches.
# augment             : bool, optional(default=True)
#                       Rotate the patches in XY-Plane and flip them along X-Axis. This only works if the patches are square in XY.
# shuffle             : bool, optional(default=False)
#                       Shuffles extracted patches across all given images (data).
#
# Returns
# -------
# patches : array(float)
#           Numpy-Array with the patches. The dimensions are 'SZYXC' or 'SYXC'
# File:      ~/Documents/codefiles/low_level/denoise/n2v/n2v/internals/N2V_DataGenerator.py
# Type:      method

# %%
# Let's look at two patches.
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.imshow(X[0,...])
plt.title('Training Patch');
plt.subplot(1,2,2)
plt.imshow(X_val[0,...])
plt.title('Validation Patch');

# %% [markdown]
# # Configure

# %% [markdown]
# Noise2Void comes with a special config-object, where we store network-architecture and training specific parameters. See the docstring of the <code>N2VConfig</code> constructor for a description of all parameters.
#
# When creating the config-object, we provide the training data <code>X</code>. From <code>X</code> we extract <code>mean</code> and <code>std</code> that will be used to normalize all data before it is processed by the network. We also extract the dimensionality and number of channels from <code>X</code>.
#
# Compared to supervised training (i.e. traditional CARE), we recommend to use N2V with an increased <code>train_batch_size</code> and <code>batch_norm</code>.
# Compared to working with single channel data, we also recommend to use a deeper network with more feature channels.
# To keep the network from learning the identity we have to manipulate the input pixels during training. For this we have the parameter <code>n2v_manipulator</code> with default value <code>'uniform_withCP'</code>. Most pixel manipulators will compute the replacement value based on a neighborhood. With <code>n2v_neighborhood_radius</code> we can control its size.
#
# Other pixel manipulators:
# * normal_withoutCP: samples the neighborhood according to a normal gaussian distribution, but without the center pixel
# * normal_additive: adds a random number to the original pixel value. The random number is sampled from a gaussian distribution with zero-mean and sigma = <code>n2v_neighborhood_radius</code>
# * normal_fitted: uses a random value from a gaussian normal distribution with mean equal to the mean of the neighborhood and standard deviation equal to the standard deviation of the neighborhood.
# * identity: performs no pixel manipulation
#
# For faster training multiple pixels per input patch can be manipulated. In our experiments we manipulated about 0.198% of the input pixels per patch. For a patch size of 64 by 64 pixels this corresponds to about 8 pixels. This fraction can be tuned via <code>n2v_perc_pix</code>.
#
# For Noise2Void training it is possible to pass arbitrarily large patches to the training method. From these patches random subpatches of size <code>n2v_patch_shape</code> are extracted during training. Default patch shape is set to (64, 64).

# %% [markdown]
# <font color='red'>Warning:</font> to make this example notebook execute faster, we have set <code>train_epochs</code> to only 25. <br>For better results we suggest 100 to 200 <code>train_epochs</code>.

# %%
# train_steps_per_epoch is set to (number of training patches)/(batch size), like this each training patch 
# is shown once per epoch. 
config = N2VConfig(X, unet_kern_size=3, 
                   unet_n_first=64, unet_n_depth=3, train_steps_per_epoch=int(X.shape[0]/batch_size), train_epochs=epochs, train_loss='mse', 
                   batch_norm=True, train_batch_size=batch_size, n2v_perc_pix=0.198, n2v_patch_shape=(patch_size, patch_size), 
                   unet_residual = True,
                   n2v_manipulator='uniform_withCP', n2v_neighborhood_radius=n2v_neighborhood_radius)

# Let's look at the parameters stored in the config-object.
vars(config)
# Out:
# {'means': ['0.598396177791126', '0.4490735195502014', '0.4181017847205786'],
#  'stds': ['0.3289747387269463', '0.29380426026317297', '0.27866817271305205'],
#  'n_dim': 2,
#  'axes': 'YXC',
#  'n_channel_in': 3,
#  'n_channel_out': 3,
#  'unet_residual': True,
#  'unet_n_depth': 3,
#  'unet_kern_size': 3,
#  'unet_n_first': 64,
#  'unet_last_activation': 'linear',
#  'unet_input_shape': (None, None, 3),
#  'train_loss': 'mse',
#  'train_epochs': 500,
#  'train_steps_per_epoch': 8,
#  'train_learning_rate': 0.0004,
#  'train_batch_size': 64,
#  'train_tensorboard': True,
#  'train_checkpoint': 'weights_best.h5',
#  'train_reduce_lr': {'factor': 0.5, 'patience': 10},
#  'batch_norm': True,
#  'n2v_perc_pix': 0.198,
#  'n2v_patch_shape': (32, 32),
#  'n2v_manipulator': 'uniform_withCP',
#  'n2v_neighborhood_radius': 2,
#  'probabilistic': False}

# %%
# a name used to identify the model --> change this to something sensible!
model_name = 'n2v_2D'
# the base directory in which our model will live
basedir = 'models'
# We are now creating our network model.
model = N2V(config, model_name, basedir=basedir)
# Out:
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# /home/qiang/Documents/codefiles/low_level/denoise/n2v/n2v/models/n2v_standard.py:409: UserWarning: output path for model already exists, files may be overwritten: /home/qiang/Documents/codefiles/low_level/denoise/n2v/examples/2D/denoising2D_RGB/models/n2v_2D
#   warnings.warn('output path for model already exists, files may be overwritten: %s' % str(self.logdir.resolve()))
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.

# %% [markdown]
# # Training
#
# Training the model will likely take some time. We recommend to monitor the progress with TensorBoard, which allows you to inspect the losses during training. Furthermore, you can look at the predictions for some of the validation images, which can be helpful to recognize problems early on.
#
# You can start TensorBoard in a terminal from the current working directory with tensorboard --logdir=. Then connect to http://localhost:6006/ with your browser.

# %%
history = model.train(X, X_val)
# Out:
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# Preparing validation data: 100%|██████████| 112/112 [00:00<00:00, 1716.16it/s]
# 2 blind-spots will be generated per training patch of size (32, 32).
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/csbdeep/utils/tf.py:240: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/csbdeep/utils/tf.py:268: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/csbdeep/utils/tf.py:275: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/500
# 8/8 [==============================] - 4s 510ms/step - loss: 0.6865 - n2v_mse: 0.6865 - n2v_abs: 0.6423 - val_loss: 2.0835 - val_n2v_mse: 2.0835 - val_n2v_abs: 1.0895
# Epoch 2/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.4712 - n2v_mse: 0.4712 - n2v_abs: 0.5357 - val_loss: 4.5218 - val_n2v_mse: 4.5218 - val_n2v_abs: 1.5725
# Epoch 3/500
# 8/8 [==============================] - 1s 72ms/step - loss: 0.3290 - n2v_mse: 0.3290 - n2v_abs: 0.4478 - val_loss: 12.9299 - val_n2v_mse: 12.9299 - val_n2v_abs: 2.4939
# Epoch 4/500
# 8/8 [==============================] - 1s 64ms/step - loss: 0.2785 - n2v_mse: 0.2785 - n2v_abs: 0.4083 - val_loss: 8.7093 - val_n2v_mse: 8.7093 - val_n2v_abs: 1.9543
# Epoch 5/500
# 8/8 [==============================] - 1s 63ms/step - loss: 0.2291 - n2v_mse: 0.2291 - n2v_abs: 0.3704 - val_loss: 3.0755 - val_n2v_mse: 3.0755 - val_n2v_abs: 1.1578
# Epoch 6/500
# 8/8 [==============================] - 0s 60ms/step - loss: 0.2206 - n2v_mse: 0.2206 - n2v_abs: 0.3633 - val_loss: 1.2809 - val_n2v_mse: 1.2809 - val_n2v_abs: 0.7912
# Epoch 7/500
# 8/8 [==============================] - 1s 66ms/step - loss: 0.2098 - n2v_mse: 0.2098 - n2v_abs: 0.3544 - val_loss: 1.0401 - val_n2v_mse: 1.0401 - val_n2v_abs: 0.6540
# Epoch 8/500
# 8/8 [==============================] - 0s 60ms/step - loss: 0.2088 - n2v_mse: 0.2088 - n2v_abs: 0.3546 - val_loss: 0.5994 - val_n2v_mse: 0.5994 - val_n2v_abs: 0.5721
# Epoch 9/500
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1964 - n2v_mse: 0.1964 - n2v_abs: 0.3462 - val_loss: 0.4545 - val_n2v_mse: 0.4545 - val_n2v_abs: 0.4780
# Epoch 10/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1858 - n2v_mse: 0.1858 - n2v_abs: 0.3341 - val_loss: 0.3283 - val_n2v_mse: 0.3283 - val_n2v_abs: 0.4260
# Epoch 11/500
# 8/8 [==============================] - 1s 82ms/step - loss: 0.1711 - n2v_mse: 0.1711 - n2v_abs: 0.3215 - val_loss: 0.3581 - val_n2v_mse: 0.3581 - val_n2v_abs: 0.4477
# Epoch 12/500
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1653 - n2v_mse: 0.1653 - n2v_abs: 0.3170 - val_loss: 0.3007 - val_n2v_mse: 0.3007 - val_n2v_abs: 0.4129
# Epoch 13/500
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1755 - n2v_mse: 0.1755 - n2v_abs: 0.3256 - val_loss: 0.3460 - val_n2v_mse: 0.3460 - val_n2v_abs: 0.4326
# Epoch 14/500
# 8/8 [==============================] - 1s 64ms/step - loss: 0.1720 - n2v_mse: 0.1720 - n2v_abs: 0.3234 - val_loss: 0.2595 - val_n2v_mse: 0.2595 - val_n2v_abs: 0.3943
# Epoch 15/500
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1663 - n2v_mse: 0.1663 - n2v_abs: 0.3165 - val_loss: 0.2518 - val_n2v_mse: 0.2518 - val_n2v_abs: 0.3864
# Epoch 16/500
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1597 - n2v_mse: 0.1597 - n2v_abs: 0.3138 - val_loss: 0.2269 - val_n2v_mse: 0.2269 - val_n2v_abs: 0.3683
# Epoch 17/500
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1600 - n2v_mse: 0.1600 - n2v_abs: 0.3125 - val_loss: 0.2229 - val_n2v_mse: 0.2229 - val_n2v_abs: 0.3674
# Epoch 18/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1573 - n2v_mse: 0.1573 - n2v_abs: 0.3121 - val_loss: 0.2016 - val_n2v_mse: 0.2016 - val_n2v_abs: 0.3494
# Epoch 19/500
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1544 - n2v_mse: 0.1544 - n2v_abs: 0.3129 - val_loss: 0.2007 - val_n2v_mse: 0.2007 - val_n2v_abs: 0.3487
# Epoch 20/500
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1473 - n2v_mse: 0.1473 - n2v_abs: 0.2976 - val_loss: 0.1974 - val_n2v_mse: 0.1974 - val_n2v_abs: 0.3450
# Epoch 21/500
# 8/8 [==============================] - 1s 77ms/step - loss: 0.1435 - n2v_mse: 0.1435 - n2v_abs: 0.2976 - val_loss: 0.1915 - val_n2v_mse: 0.1915 - val_n2v_abs: 0.3409
# Epoch 22/500
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1419 - n2v_mse: 0.1419 - n2v_abs: 0.2936 - val_loss: 0.1829 - val_n2v_mse: 0.1829 - val_n2v_abs: 0.3332
# Epoch 23/500
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1446 - n2v_mse: 0.1446 - n2v_abs: 0.2963 - val_loss: 0.1869 - val_n2v_mse: 0.1869 - val_n2v_abs: 0.3377
# Epoch 24/500
# 8/8 [==============================] - 1s 64ms/step - loss: 0.1444 - n2v_mse: 0.1444 - n2v_abs: 0.2983 - val_loss: 0.1888 - val_n2v_mse: 0.1888 - val_n2v_abs: 0.3381
# Epoch 25/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1396 - n2v_mse: 0.1396 - n2v_abs: 0.2961 - val_loss: 0.1884 - val_n2v_mse: 0.1884 - val_n2v_abs: 0.3380
# Epoch 26/500
# 8/8 [==============================] - 1s 74ms/step - loss: 0.1404 - n2v_mse: 0.1404 - n2v_abs: 0.2934 - val_loss: 0.1818 - val_n2v_mse: 0.1818 - val_n2v_abs: 0.3304
# Epoch 27/500
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1442 - n2v_mse: 0.1442 - n2v_abs: 0.2961 - val_loss: 0.1815 - val_n2v_mse: 0.1815 - val_n2v_abs: 0.3303
# Epoch 28/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1387 - n2v_mse: 0.1387 - n2v_abs: 0.2919 - val_loss: 0.1728 - val_n2v_mse: 0.1728 - val_n2v_abs: 0.3241
# Epoch 29/500
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1340 - n2v_mse: 0.1340 - n2v_abs: 0.2907 - val_loss: 0.1718 - val_n2v_mse: 0.1718 - val_n2v_abs: 0.3245
# Epoch 30/500
# 8/8 [==============================] - 1s 80ms/step - loss: 0.1410 - n2v_mse: 0.1410 - n2v_abs: 0.2922 - val_loss: 0.1715 - val_n2v_mse: 0.1715 - val_n2v_abs: 0.3244
# Epoch 31/500
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1406 - n2v_mse: 0.1406 - n2v_abs: 0.2930 - val_loss: 0.1773 - val_n2v_mse: 0.1773 - val_n2v_abs: 0.3271
# Epoch 32/500
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1393 - n2v_mse: 0.1393 - n2v_abs: 0.2924 - val_loss: 0.1687 - val_n2v_mse: 0.1687 - val_n2v_abs: 0.3170
# Epoch 33/500
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1338 - n2v_mse: 0.1338 - n2v_abs: 0.2846 - val_loss: 0.1647 - val_n2v_mse: 0.1647 - val_n2v_abs: 0.3176
# Epoch 34/500
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1283 - n2v_mse: 0.1283 - n2v_abs: 0.2837 - val_loss: 0.1676 - val_n2v_mse: 0.1676 - val_n2v_abs: 0.3206
# Epoch 35/500
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1374 - n2v_mse: 0.1374 - n2v_abs: 0.2909 - val_loss: 0.1674 - val_n2v_mse: 0.1674 - val_n2v_abs: 0.3190
# Epoch 36/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1381 - n2v_mse: 0.1381 - n2v_abs: 0.2906 - val_loss: 0.1669 - val_n2v_mse: 0.1669 - val_n2v_abs: 0.3199
# Epoch 37/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1313 - n2v_mse: 0.1313 - n2v_abs: 0.2872 - val_loss: 0.1674 - val_n2v_mse: 0.1674 - val_n2v_abs: 0.3187
# Epoch 38/500
# 8/8 [==============================] - 1s 81ms/step - loss: 0.1368 - n2v_mse: 0.1368 - n2v_abs: 0.2917 - val_loss: 0.1649 - val_n2v_mse: 0.1649 - val_n2v_abs: 0.3178
# Epoch 39/500
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1340 - n2v_mse: 0.1340 - n2v_abs: 0.2869 - val_loss: 0.1625 - val_n2v_mse: 0.1625 - val_n2v_abs: 0.3176
# Epoch 40/500
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1357 - n2v_mse: 0.1357 - n2v_abs: 0.2903 - val_loss: 0.1592 - val_n2v_mse: 0.1592 - val_n2v_abs: 0.3142
# Epoch 41/500
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1315 - n2v_mse: 0.1315 - n2v_abs: 0.2829 - val_loss: 0.1562 - val_n2v_mse: 0.1562 - val_n2v_abs: 0.3112
# Epoch 42/500
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1275 - n2v_mse: 0.1275 - n2v_abs: 0.2799 - val_loss: 0.1554 - val_n2v_mse: 0.1554 - val_n2v_abs: 0.3108
# Epoch 43/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1245 - n2v_mse: 0.1245 - n2v_abs: 0.2794 - val_loss: 0.1511 - val_n2v_mse: 0.1511 - val_n2v_abs: 0.3050
# Epoch 44/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1298 - n2v_mse: 0.1298 - n2v_abs: 0.2833 - val_loss: 0.1531 - val_n2v_mse: 0.1531 - val_n2v_abs: 0.3069
# Epoch 45/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1323 - n2v_mse: 0.1323 - n2v_abs: 0.2852 - val_loss: 0.1525 - val_n2v_mse: 0.1525 - val_n2v_abs: 0.3062
# Epoch 46/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1331 - n2v_mse: 0.1331 - n2v_abs: 0.2863 - val_loss: 0.1528 - val_n2v_mse: 0.1528 - val_n2v_abs: 0.3075
# Epoch 47/500
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1282 - n2v_mse: 0.1282 - n2v_abs: 0.2850 - val_loss: 0.1540 - val_n2v_mse: 0.1540 - val_n2v_abs: 0.3092
# Epoch 48/500
# 8/8 [==============================] - 1s 79ms/step - loss: 0.1266 - n2v_mse: 0.1266 - n2v_abs: 0.2769 - val_loss: 0.1521 - val_n2v_mse: 0.1521 - val_n2v_abs: 0.3077
# Epoch 49/500
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1263 - n2v_mse: 0.1263 - n2v_abs: 0.2789 - val_loss: 0.1552 - val_n2v_mse: 0.1552 - val_n2v_abs: 0.3094
# Epoch 50/500
# 8/8 [==============================] - 1s 64ms/step - loss: 0.1292 - n2v_mse: 0.1292 - n2v_abs: 0.2849 - val_loss: 0.1497 - val_n2v_mse: 0.1497 - val_n2v_abs: 0.3050
# Epoch 51/500
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1238 - n2v_mse: 0.1238 - n2v_abs: 0.2786 - val_loss: 0.1581 - val_n2v_mse: 0.1581 - val_n2v_abs: 0.3130
# Epoch 52/500
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1274 - n2v_mse: 0.1274 - n2v_abs: 0.2807 - val_loss: 0.1489 - val_n2v_mse: 0.1489 - val_n2v_abs: 0.3042
# Epoch 53/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1271 - n2v_mse: 0.1271 - n2v_abs: 0.2794 - val_loss: 0.1529 - val_n2v_mse: 0.1529 - val_n2v_abs: 0.3060
# Epoch 54/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1240 - n2v_mse: 0.1240 - n2v_abs: 0.2767 - val_loss: 0.1476 - val_n2v_mse: 0.1476 - val_n2v_abs: 0.3009
# Epoch 55/500
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1266 - n2v_mse: 0.1266 - n2v_abs: 0.2827 - val_loss: 0.1465 - val_n2v_mse: 0.1465 - val_n2v_abs: 0.2987
# Epoch 56/500
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1244 - n2v_mse: 0.1244 - n2v_abs: 0.2761 - val_loss: 0.1476 - val_n2v_mse: 0.1476 - val_n2v_abs: 0.2988
# Epoch 57/500
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1258 - n2v_mse: 0.1258 - n2v_abs: 0.2785 - val_loss: 0.1485 - val_n2v_mse: 0.1485 - val_n2v_abs: 0.3012
# Epoch 58/500
# 8/8 [==============================] - 1s 93ms/step - loss: 0.1219 - n2v_mse: 0.1219 - n2v_abs: 0.2755 - val_loss: 0.1459 - val_n2v_mse: 0.1459 - val_n2v_abs: 0.2981
# Epoch 59/500
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1276 - n2v_mse: 0.1276 - n2v_abs: 0.2810 - val_loss: 0.1473 - val_n2v_mse: 0.1473 - val_n2v_abs: 0.2988
# Epoch 60/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1238 - n2v_mse: 0.1238 - n2v_abs: 0.2746 - val_loss: 0.1483 - val_n2v_mse: 0.1483 - val_n2v_abs: 0.3015
# Epoch 61/500
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1280 - n2v_mse: 0.1280 - n2v_abs: 0.2824 - val_loss: 0.1488 - val_n2v_mse: 0.1488 - val_n2v_abs: 0.3010
# Epoch 62/500
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1279 - n2v_mse: 0.1279 - n2v_abs: 0.2807 - val_loss: 0.1491 - val_n2v_mse: 0.1491 - val_n2v_abs: 0.3029
# Epoch 63/500
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1204 - n2v_mse: 0.1204 - n2v_abs: 0.2783 - val_loss: 0.1452 - val_n2v_mse: 0.1452 - val_n2v_abs: 0.2970
# Epoch 64/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1214 - n2v_mse: 0.1214 - n2v_abs: 0.2769 - val_loss: 0.1466 - val_n2v_mse: 0.1466 - val_n2v_abs: 0.2989
# Epoch 65/500
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1251 - n2v_mse: 0.1251 - n2v_abs: 0.2792 - val_loss: 0.1457 - val_n2v_mse: 0.1457 - val_n2v_abs: 0.2968
# Epoch 66/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1241 - n2v_mse: 0.1241 - n2v_abs: 0.2794 - val_loss: 0.1442 - val_n2v_mse: 0.1442 - val_n2v_abs: 0.2966
# Epoch 67/500
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1262 - n2v_mse: 0.1262 - n2v_abs: 0.2797 - val_loss: 0.1445 - val_n2v_mse: 0.1445 - val_n2v_abs: 0.2972
# Epoch 68/500
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1277 - n2v_mse: 0.1277 - n2v_abs: 0.2793 - val_loss: 0.1469 - val_n2v_mse: 0.1469 - val_n2v_abs: 0.3013
# Epoch 69/500
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1256 - n2v_mse: 0.1256 - n2v_abs: 0.2806 - val_loss: 0.1499 - val_n2v_mse: 0.1499 - val_n2v_abs: 0.3066
# Epoch 70/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1135 - n2v_mse: 0.1135 - n2v_abs: 0.2656 - val_loss: 0.1433 - val_n2v_mse: 0.1433 - val_n2v_abs: 0.2961
# Epoch 71/500
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1181 - n2v_mse: 0.1181 - n2v_abs: 0.2710 - val_loss: 0.1450 - val_n2v_mse: 0.1450 - val_n2v_abs: 0.3011
# Epoch 72/500
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1211 - n2v_mse: 0.1211 - n2v_abs: 0.2733 - val_loss: 0.1462 - val_n2v_mse: 0.1462 - val_n2v_abs: 0.3012
# Epoch 73/500
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1202 - n2v_mse: 0.1202 - n2v_abs: 0.2736 - val_loss: 0.1454 - val_n2v_mse: 0.1454 - val_n2v_abs: 0.3000
# Epoch 74/500
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1242 - n2v_mse: 0.1242 - n2v_abs: 0.2777 - val_loss: 0.1426 - val_n2v_mse: 0.1426 - val_n2v_abs: 0.2966
# Epoch 75/500
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1246 - n2v_mse: 0.1246 - n2v_abs: 0.2774 - val_loss: 0.1422 - val_n2v_mse: 0.1422 - val_n2v_abs: 0.2978
# Epoch 76/500
# 8/8 [==============================] - 0s 59ms/step - loss: 0.1177 - n2v_mse: 0.1177 - n2v_abs: 0.2726 - val_loss: 0.1399 - val_n2v_mse: 0.1399 - val_n2v_abs: 0.2928
# Epoch 77/500
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1234 - n2v_mse: 0.1234 - n2v_abs: 0.2797 - val_loss: 0.1420 - val_n2v_mse: 0.1420 - val_n2v_abs: 0.2951
# Epoch 78/500
# 8/8 [==============================] - 1s 83ms/step - loss: 0.1173 - n2v_mse: 0.1173 - n2v_abs: 0.2702 - val_loss: 0.1392 - val_n2v_mse: 0.1392 - val_n2v_abs: 0.2922
# Epoch 79/500
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1208 - n2v_mse: 0.1208 - n2v_abs: 0.2753 - val_loss: 0.1394 - val_n2v_mse: 0.1394 - val_n2v_abs: 0.2917
# Epoch 80/500
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1173 - n2v_mse: 0.1173 - n2v_abs: 0.2694 - val_loss: 0.1412 - val_n2v_mse: 0.1412 - val_n2v_abs: 0.2933
# Epoch 81/500
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1217 - n2v_mse: 0.1217 - n2v_abs: 0.2752 - val_loss: 0.1411 - val_n2v_mse: 0.1411 - val_n2v_abs: 0.2928
# Epoch 82/500
# 8/8 [==============================] - 0s 39ms/step - loss: 0.1177 - n2v_mse: 0.1177 - n2v_abs: 0.2685 - val_loss: 0.1415 - val_n2v_mse: 0.1415 - val_n2v_abs: 0.2944
# Epoch 83/500
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1178 - n2v_mse: 0.1178 - n2v_abs: 0.2735 - val_loss: 0.1444 - val_n2v_mse: 0.1444 - val_n2v_abs: 0.2977
# Epoch 84/500
# 8/8 [==============================] - 1s 74ms/step - loss: 0.1224 - n2v_mse: 0.1224 - n2v_abs: 0.2784 - val_loss: 0.1444 - val_n2v_mse: 0.1444 - val_n2v_abs: 0.2976
# Epoch 85/500
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1196 - n2v_mse: 0.1196 - n2v_abs: 0.2745 - val_loss: 0.1452 - val_n2v_mse: 0.1452 - val_n2v_abs: 0.2993
# Epoch 86/500
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1171 - n2v_mse: 0.1171 - n2v_abs: 0.2705 - val_loss: 0.1453 - val_n2v_mse: 0.1453 - val_n2v_abs: 0.3003
# Epoch 87/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1236 - n2v_mse: 0.1236 - n2v_abs: 0.2788 - val_loss: 0.1453 - val_n2v_mse: 0.1453 - val_n2v_abs: 0.2991
# Epoch 88/500
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1197 - n2v_mse: 0.1197 - n2v_abs: 0.2739 - val_loss: 0.1447 - val_n2v_mse: 0.1447 - val_n2v_abs: 0.2976
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# Epoch 89/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1132 - n2v_mse: 0.1132 - n2v_abs: 0.2654 - val_loss: 0.1428 - val_n2v_mse: 0.1428 - val_n2v_abs: 0.2968
# Epoch 90/500
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1148 - n2v_mse: 0.1148 - n2v_abs: 0.2690 - val_loss: 0.1466 - val_n2v_mse: 0.1466 - val_n2v_abs: 0.3015
# Epoch 91/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1200 - n2v_mse: 0.1200 - n2v_abs: 0.2712 - val_loss: 0.1420 - val_n2v_mse: 0.1420 - val_n2v_abs: 0.2945
# Epoch 92/500
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1162 - n2v_mse: 0.1162 - n2v_abs: 0.2692 - val_loss: 0.1415 - val_n2v_mse: 0.1415 - val_n2v_abs: 0.2931
# Epoch 93/500
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1130 - n2v_mse: 0.1130 - n2v_abs: 0.2644 - val_loss: 0.1413 - val_n2v_mse: 0.1413 - val_n2v_abs: 0.2935
# Epoch 94/500
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1170 - n2v_mse: 0.1170 - n2v_abs: 0.2710 - val_loss: 0.1412 - val_n2v_mse: 0.1412 - val_n2v_abs: 0.2938
# Epoch 95/500
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1192 - n2v_mse: 0.1192 - n2v_abs: 0.2735 - val_loss: 0.1399 - val_n2v_mse: 0.1399 - val_n2v_abs: 0.2913
# Epoch 96/500
# 8/8 [==============================] - 0s 59ms/step - loss: 0.1180 - n2v_mse: 0.1180 - n2v_abs: 0.2731 - val_loss: 0.1391 - val_n2v_mse: 0.1391 - val_n2v_abs: 0.2913
# Epoch 97/500
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1135 - n2v_mse: 0.1135 - n2v_abs: 0.2679 - val_loss: 0.1388 - val_n2v_mse: 0.1388 - val_n2v_abs: 0.2906
# Epoch 98/500
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1091 - n2v_mse: 0.1091 - n2v_abs: 0.2607 - val_loss: 0.1389 - val_n2v_mse: 0.1389 - val_n2v_abs: 0.2897
# Epoch 99/500
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1164 - n2v_mse: 0.1164 - n2v_abs: 0.2707 - val_loss: 0.1391 - val_n2v_mse: 0.1391 - val_n2v_abs: 0.2903
# Epoch 100/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1083 - n2v_mse: 0.1083 - n2v_abs: 0.2628 - val_loss: 0.1383 - val_n2v_mse: 0.1383 - val_n2v_abs: 0.2894
# Epoch 101/500
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1160 - n2v_mse: 0.1160 - n2v_abs: 0.2681 - val_loss: 0.1391 - val_n2v_mse: 0.1391 - val_n2v_abs: 0.2903
# Epoch 102/500
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1170 - n2v_mse: 0.1170 - n2v_abs: 0.2709 - val_loss: 0.1390 - val_n2v_mse: 0.1390 - val_n2v_abs: 0.2904
# Epoch 103/500
# 8/8 [==============================] - 1s 84ms/step - loss: 0.1166 - n2v_mse: 0.1166 - n2v_abs: 0.2676 - val_loss: 0.1393 - val_n2v_mse: 0.1393 - val_n2v_abs: 0.2909
# Epoch 104/500
# 8/8 [==============================] - 1s 77ms/step - loss: 0.1171 - n2v_mse: 0.1171 - n2v_abs: 0.2708 - val_loss: 0.1396 - val_n2v_mse: 0.1396 - val_n2v_abs: 0.2916
# Epoch 105/500
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1182 - n2v_mse: 0.1182 - n2v_abs: 0.2719 - val_loss: 0.1397 - val_n2v_mse: 0.1397 - val_n2v_abs: 0.2922
# Epoch 106/500
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1209 - n2v_mse: 0.1209 - n2v_abs: 0.2772 - val_loss: 0.1393 - val_n2v_mse: 0.1393 - val_n2v_abs: 0.2905
# Epoch 107/500
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1149 - n2v_mse: 0.1149 - n2v_abs: 0.2684 - val_loss: 0.1387 - val_n2v_mse: 0.1387 - val_n2v_abs: 0.2899
# Epoch 108/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1127 - n2v_mse: 0.1127 - n2v_abs: 0.2683 - val_loss: 0.1378 - val_n2v_mse: 0.1378 - val_n2v_abs: 0.2892
# Epoch 109/500
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1149 - n2v_mse: 0.1149 - n2v_abs: 0.2671 - val_loss: 0.1371 - val_n2v_mse: 0.1371 - val_n2v_abs: 0.2894
# Epoch 110/500
# 8/8 [==============================] - 1s 87ms/step - loss: 0.1182 - n2v_mse: 0.1182 - n2v_abs: 0.2718 - val_loss: 0.1384 - val_n2v_mse: 0.1384 - val_n2v_abs: 0.2916
# Epoch 111/500
# 8/8 [==============================] - 1s 77ms/step - loss: 0.1181 - n2v_mse: 0.1181 - n2v_abs: 0.2738 - val_loss: 0.1369 - val_n2v_mse: 0.1369 - val_n2v_abs: 0.2889
# Epoch 112/500
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1135 - n2v_mse: 0.1135 - n2v_abs: 0.2684 - val_loss: 0.1369 - val_n2v_mse: 0.1369 - val_n2v_abs: 0.2884
# Epoch 113/500
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1176 - n2v_mse: 0.1176 - n2v_abs: 0.2732 - val_loss: 0.1369 - val_n2v_mse: 0.1369 - val_n2v_abs: 0.2887
# Epoch 114/500
# 8/8 [==============================] - 1s 64ms/step - loss: 0.1149 - n2v_mse: 0.1149 - n2v_abs: 0.2686 - val_loss: 0.1374 - val_n2v_mse: 0.1374 - val_n2v_abs: 0.2881
# Epoch 115/500
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1158 - n2v_mse: 0.1158 - n2v_abs: 0.2672 - val_loss: 0.1375 - val_n2v_mse: 0.1375 - val_n2v_abs: 0.2898
# Epoch 116/500
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1217 - n2v_mse: 0.1217 - n2v_abs: 0.2752 - val_loss: 0.1386 - val_n2v_mse: 0.1386 - val_n2v_abs: 0.2907
# Epoch 117/500
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1060 - n2v_mse: 0.1060 - n2v_abs: 0.2606 - val_loss: 0.1394 - val_n2v_mse: 0.1394 - val_n2v_abs: 0.2912
# Epoch 118/500
# 8/8 [==============================] - 0s 59ms/step - loss: 0.1134 - n2v_mse: 0.1134 - n2v_abs: 0.2676 - val_loss: 0.1367 - val_n2v_mse: 0.1367 - val_n2v_abs: 0.2871
# Epoch 119/500
# 8/8 [==============================] - 1s 83ms/step - loss: 0.1153 - n2v_mse: 0.1153 - n2v_abs: 0.2682 - val_loss: 0.1381 - val_n2v_mse: 0.1381 - val_n2v_abs: 0.2901
# Epoch 120/500
# 8/8 [==============================] - 1s 64ms/step - loss: 0.1132 - n2v_mse: 0.1132 - n2v_abs: 0.2671 - val_loss: 0.1411 - val_n2v_mse: 0.1411 - val_n2v_abs: 0.2918
# Epoch 121/500
# 8/8 [==============================] - 1s 77ms/step - loss: 0.1169 - n2v_mse: 0.1169 - n2v_abs: 0.2696 - val_loss: 0.1385 - val_n2v_mse: 0.1385 - val_n2v_abs: 0.2897
# Epoch 122/500
# 8/8 [==============================] - 1s 77ms/step - loss: 0.1152 - n2v_mse: 0.1152 - n2v_abs: 0.2697 - val_loss: 0.1381 - val_n2v_mse: 0.1381 - val_n2v_abs: 0.2888
# Epoch 123/500
# 8/8 [==============================] - 1s 77ms/step - loss: 0.1136 - n2v_mse: 0.1136 - n2v_abs: 0.2663 - val_loss: 0.1380 - val_n2v_mse: 0.1380 - val_n2v_abs: 0.2901
# Epoch 124/500
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1109 - n2v_mse: 0.1109 - n2v_abs: 0.2634 - val_loss: 0.1361 - val_n2v_mse: 0.1361 - val_n2v_abs: 0.2886
# Epoch 125/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1141 - n2v_mse: 0.1141 - n2v_abs: 0.2669 - val_loss: 0.1347 - val_n2v_mse: 0.1347 - val_n2v_abs: 0.2869
# Epoch 126/500
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1165 - n2v_mse: 0.1165 - n2v_abs: 0.2677 - val_loss: 0.1363 - val_n2v_mse: 0.1363 - val_n2v_abs: 0.2874
# Epoch 127/500
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1109 - n2v_mse: 0.1109 - n2v_abs: 0.2632 - val_loss: 0.1361 - val_n2v_mse: 0.1361 - val_n2v_abs: 0.2884
# Epoch 128/500
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1100 - n2v_mse: 0.1100 - n2v_abs: 0.2626 - val_loss: 0.1364 - val_n2v_mse: 0.1364 - val_n2v_abs: 0.2881
# Epoch 129/500
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1128 - n2v_mse: 0.1128 - n2v_abs: 0.2657 - val_loss: 0.1370 - val_n2v_mse: 0.1370 - val_n2v_abs: 0.2890
# Epoch 130/500
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1187 - n2v_mse: 0.1187 - n2v_abs: 0.2733 - val_loss: 0.1360 - val_n2v_mse: 0.1360 - val_n2v_abs: 0.2880
# Epoch 131/500
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1149 - n2v_mse: 0.1149 - n2v_abs: 0.2679 - val_loss: 0.1380 - val_n2v_mse: 0.1380 - val_n2v_abs: 0.2901
# Epoch 132/500
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1122 - n2v_mse: 0.1122 - n2v_abs: 0.2634 - val_loss: 0.1405 - val_n2v_mse: 0.1405 - val_n2v_abs: 0.2921
# Epoch 133/500
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1134 - n2v_mse: 0.1134 - n2v_abs: 0.2686 - val_loss: 0.1382 - val_n2v_mse: 0.1382 - val_n2v_abs: 0.2912
# Epoch 134/500
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1129 - n2v_mse: 0.1129 - n2v_abs: 0.2654 - val_loss: 0.1368 - val_n2v_mse: 0.1368 - val_n2v_abs: 0.2888
# Epoch 135/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1097 - n2v_mse: 0.1097 - n2v_abs: 0.2619 - val_loss: 0.1388 - val_n2v_mse: 0.1388 - val_n2v_abs: 0.2909
#
# Epoch 00135: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 136/500
# 8/8 [==============================] - 0s 40ms/step - loss: 0.1126 - n2v_mse: 0.1126 - n2v_abs: 0.2629 - val_loss: 0.1374 - val_n2v_mse: 0.1374 - val_n2v_abs: 0.2886
# Epoch 137/500
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1146 - n2v_mse: 0.1146 - n2v_abs: 0.2681 - val_loss: 0.1367 - val_n2v_mse: 0.1367 - val_n2v_abs: 0.2881
# Epoch 138/500
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1055 - n2v_mse: 0.1055 - n2v_abs: 0.2560 - val_loss: 0.1375 - val_n2v_mse: 0.1375 - val_n2v_abs: 0.2896
# Epoch 139/500
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1201 - n2v_mse: 0.1201 - n2v_abs: 0.2729 - val_loss: 0.1373 - val_n2v_mse: 0.1373 - val_n2v_abs: 0.2891
# Epoch 140/500
# 8/8 [==============================] - 1s 64ms/step - loss: 0.1108 - n2v_mse: 0.1108 - n2v_abs: 0.2617 - val_loss: 0.1369 - val_n2v_mse: 0.1369 - val_n2v_abs: 0.2882
# Epoch 141/500
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1158 - n2v_mse: 0.1158 - n2v_abs: 0.2715 - val_loss: 0.1364 - val_n2v_mse: 0.1364 - val_n2v_abs: 0.2882
# Epoch 142/500
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1122 - n2v_mse: 0.1122 - n2v_abs: 0.2661 - val_loss: 0.1357 - val_n2v_mse: 0.1357 - val_n2v_abs: 0.2877
# Epoch 143/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1111 - n2v_mse: 0.1111 - n2v_abs: 0.2658 - val_loss: 0.1364 - val_n2v_mse: 0.1364 - val_n2v_abs: 0.2881
# Epoch 144/500
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1134 - n2v_mse: 0.1134 - n2v_abs: 0.2661 - val_loss: 0.1363 - val_n2v_mse: 0.1363 - val_n2v_abs: 0.2877
# Epoch 145/500
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1129 - n2v_mse: 0.1129 - n2v_abs: 0.2686 - val_loss: 0.1358 - val_n2v_mse: 0.1358 - val_n2v_abs: 0.2876
#
# Epoch 00145: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 146/500
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1138 - n2v_mse: 0.1138 - n2v_abs: 0.2671 - val_loss: 0.1364 - val_n2v_mse: 0.1364 - val_n2v_abs: 0.2880
# Epoch 147/500
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1139 - n2v_mse: 0.1139 - n2v_abs: 0.2683 - val_loss: 0.1368 - val_n2v_mse: 0.1368 - val_n2v_abs: 0.2877
# Epoch 148/500
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1058 - n2v_mse: 0.1058 - n2v_abs: 0.2589 - val_loss: 0.1365 - val_n2v_mse: 0.1365 - val_n2v_abs: 0.2875
# Epoch 149/500
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1088 - n2v_mse: 0.1088 - n2v_abs: 0.2631 - val_loss: 0.1360 - val_n2v_mse: 0.1360 - val_n2v_abs: 0.2875
# Epoch 150/500
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1116 - n2v_mse: 0.1116 - n2v_abs: 0.2643 - val_loss: 0.1355 - val_n2v_mse: 0.1355 - val_n2v_abs: 0.2872
# Epoch 151/500
# 8/8 [==============================] - 0s 59ms/step - loss: 0.1101 - n2v_mse: 0.1101 - n2v_abs: 0.2647 - val_loss: 0.1355 - val_n2v_mse: 0.1355 - val_n2v_abs: 0.2868
# Epoch 152/500
# 8/8 [==============================] - 0s 59ms/step - loss: 0.1122 - n2v_mse: 0.1122 - n2v_abs: 0.2660 - val_loss: 0.1356 - val_n2v_mse: 0.1356 - val_n2v_abs: 0.2866
# Epoch 153/500
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1144 - n2v_mse: 0.1144 - n2v_abs: 0.2705 - val_loss: 0.1354 - val_n2v_mse: 0.1354 - val_n2v_abs: 0.2866
# Epoch 154/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1118 - n2v_mse: 0.1118 - n2v_abs: 0.2636 - val_loss: 0.1351 - val_n2v_mse: 0.1351 - val_n2v_abs: 0.2867
# Epoch 155/500
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1086 - n2v_mse: 0.1086 - n2v_abs: 0.2615 - val_loss: 0.1352 - val_n2v_mse: 0.1352 - val_n2v_abs: 0.2871
#
# Epoch 00155: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 156/500
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1092 - n2v_mse: 0.1092 - n2v_abs: 0.2641 - val_loss: 0.1347 - val_n2v_mse: 0.1347 - val_n2v_abs: 0.2866
# Epoch 157/500
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1183 - n2v_mse: 0.1183 - n2v_abs: 0.2713 - val_loss: 0.1345 - val_n2v_mse: 0.1345 - val_n2v_abs: 0.2863
# Epoch 158/500
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1118 - n2v_mse: 0.1118 - n2v_abs: 0.2647 - val_loss: 0.1343 - val_n2v_mse: 0.1343 - val_n2v_abs: 0.2859
# Epoch 159/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1118 - n2v_mse: 0.1118 - n2v_abs: 0.2656 - val_loss: 0.1344 - val_n2v_mse: 0.1344 - val_n2v_abs: 0.2862
# Epoch 160/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1214 - n2v_mse: 0.1214 - n2v_abs: 0.2756 - val_loss: 0.1344 - val_n2v_mse: 0.1344 - val_n2v_abs: 0.2866
# Epoch 161/500
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1086 - n2v_mse: 0.1086 - n2v_abs: 0.2603 - val_loss: 0.1342 - val_n2v_mse: 0.1342 - val_n2v_abs: 0.2864
# Epoch 162/500
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1099 - n2v_mse: 0.1099 - n2v_abs: 0.2604 - val_loss: 0.1342 - val_n2v_mse: 0.1342 - val_n2v_abs: 0.2861
# Epoch 163/500
# 8/8 [==============================] - 0s 38ms/step - loss: 0.1096 - n2v_mse: 0.1096 - n2v_abs: 0.2630 - val_loss: 0.1343 - val_n2v_mse: 0.1343 - val_n2v_abs: 0.2862
# Epoch 164/500
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1129 - n2v_mse: 0.1129 - n2v_abs: 0.2670 - val_loss: 0.1345 - val_n2v_mse: 0.1345 - val_n2v_abs: 0.2861
# Epoch 165/500
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1099 - n2v_mse: 0.1099 - n2v_abs: 0.2611 - val_loss: 0.1347 - val_n2v_mse: 0.1347 - val_n2v_abs: 0.2861
# Epoch 166/500
# 8/8 [==============================] - 1s 64ms/step - loss: 0.1071 - n2v_mse: 0.1071 - n2v_abs: 0.2581 - val_loss: 0.1345 - val_n2v_mse: 0.1345 - val_n2v_abs: 0.2860
# Epoch 167/500
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1138 - n2v_mse: 0.1138 - n2v_abs: 0.2656 - val_loss: 0.1343 - val_n2v_mse: 0.1343 - val_n2v_abs: 0.2859
# Epoch 168/500
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1082 - n2v_mse: 0.1082 - n2v_abs: 0.2611 - val_loss: 0.1335 - val_n2v_mse: 0.1335 - val_n2v_abs: 0.2853
# Epoch 169/500
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1166 - n2v_mse: 0.1166 - n2v_abs: 0.2725 - val_loss: 0.1333 - val_n2v_mse: 0.1333 - val_n2v_abs: 0.2850
# Epoch 170/500
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1088 - n2v_mse: 0.1088 - n2v_abs: 0.2626 - val_loss: 0.1336 - val_n2v_mse: 0.1336 - val_n2v_abs: 0.2853
# Epoch 171/500
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1113 - n2v_mse: 0.1113 - n2v_abs: 0.2659 - val_loss: 0.1338 - val_n2v_mse: 0.1338 - val_n2v_abs: 0.2854
# Epoch 172/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1150 - n2v_mse: 0.1150 - n2v_abs: 0.2685 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2855
# Epoch 173/500
# 8/8 [==============================] - 1s 86ms/step - loss: 0.1088 - n2v_mse: 0.1088 - n2v_abs: 0.2606 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2855
# Epoch 174/500
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1074 - n2v_mse: 0.1074 - n2v_abs: 0.2579 - val_loss: 0.1341 - val_n2v_mse: 0.1341 - val_n2v_abs: 0.2857
# Epoch 175/500
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1101 - n2v_mse: 0.1101 - n2v_abs: 0.2640 - val_loss: 0.1342 - val_n2v_mse: 0.1342 - val_n2v_abs: 0.2858
# Epoch 176/500
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1062 - n2v_mse: 0.1062 - n2v_abs: 0.2603 - val_loss: 0.1342 - val_n2v_mse: 0.1342 - val_n2v_abs: 0.2858
# Epoch 177/500
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1103 - n2v_mse: 0.1103 - n2v_abs: 0.2645 - val_loss: 0.1342 - val_n2v_mse: 0.1342 - val_n2v_abs: 0.2858
# Epoch 178/500
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1069 - n2v_mse: 0.1069 - n2v_abs: 0.2603 - val_loss: 0.1342 - val_n2v_mse: 0.1342 - val_n2v_abs: 0.2861
# Epoch 179/500
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1105 - n2v_mse: 0.1105 - n2v_abs: 0.2628 - val_loss: 0.1344 - val_n2v_mse: 0.1344 - val_n2v_abs: 0.2862
#
# Epoch 00179: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 180/500
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1096 - n2v_mse: 0.1096 - n2v_abs: 0.2608 - val_loss: 0.1344 - val_n2v_mse: 0.1344 - val_n2v_abs: 0.2862
# Epoch 181/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1131 - n2v_mse: 0.1131 - n2v_abs: 0.2643 - val_loss: 0.1343 - val_n2v_mse: 0.1343 - val_n2v_abs: 0.2859
# Epoch 182/500
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1106 - n2v_mse: 0.1106 - n2v_abs: 0.2632 - val_loss: 0.1341 - val_n2v_mse: 0.1341 - val_n2v_abs: 0.2856
# Epoch 183/500
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1116 - n2v_mse: 0.1116 - n2v_abs: 0.2669 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2855
# Epoch 184/500
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1103 - n2v_mse: 0.1103 - n2v_abs: 0.2645 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2855
# Epoch 185/500
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1110 - n2v_mse: 0.1110 - n2v_abs: 0.2669 - val_loss: 0.1341 - val_n2v_mse: 0.1341 - val_n2v_abs: 0.2855
# Epoch 186/500
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1080 - n2v_mse: 0.1080 - n2v_abs: 0.2597 - val_loss: 0.1341 - val_n2v_mse: 0.1341 - val_n2v_abs: 0.2855
# Epoch 187/500
# 8/8 [==============================] - 0s 59ms/step - loss: 0.1131 - n2v_mse: 0.1131 - n2v_abs: 0.2647 - val_loss: 0.1341 - val_n2v_mse: 0.1341 - val_n2v_abs: 0.2856
# Epoch 188/500
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1212 - n2v_mse: 0.1212 - n2v_abs: 0.2775 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2855
# Epoch 189/500
# 8/8 [==============================] - 0s 40ms/step - loss: 0.1086 - n2v_mse: 0.1086 - n2v_abs: 0.2610 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2853
#
# Epoch 00189: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 190/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1135 - n2v_mse: 0.1135 - n2v_abs: 0.2655 - val_loss: 0.1336 - val_n2v_mse: 0.1336 - val_n2v_abs: 0.2849
# Epoch 191/500
# 8/8 [==============================] - 1s 86ms/step - loss: 0.1157 - n2v_mse: 0.1157 - n2v_abs: 0.2698 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2852
# Epoch 192/500
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1072 - n2v_mse: 0.1072 - n2v_abs: 0.2585 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 193/500
# 8/8 [==============================] - 1s 64ms/step - loss: 0.1111 - n2v_mse: 0.1111 - n2v_abs: 0.2646 - val_loss: 0.1336 - val_n2v_mse: 0.1336 - val_n2v_abs: 0.2850
# Epoch 194/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1177 - n2v_mse: 0.1177 - n2v_abs: 0.2722 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 195/500
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1075 - n2v_mse: 0.1075 - n2v_abs: 0.2595 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 196/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1137 - n2v_mse: 0.1137 - n2v_abs: 0.2683 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 197/500
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1130 - n2v_mse: 0.1130 - n2v_abs: 0.2620 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 198/500
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1079 - n2v_mse: 0.1079 - n2v_abs: 0.2623 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 199/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1112 - n2v_mse: 0.1112 - n2v_abs: 0.2620 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2852
#
# Epoch 00199: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 200/500
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1144 - n2v_mse: 0.1144 - n2v_abs: 0.2668 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2852
# Epoch 201/500
# 8/8 [==============================] - 1s 64ms/step - loss: 0.1138 - n2v_mse: 0.1138 - n2v_abs: 0.2691 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 202/500
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1088 - n2v_mse: 0.1088 - n2v_abs: 0.2599 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 203/500
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1107 - n2v_mse: 0.1107 - n2v_abs: 0.2641 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 204/500
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1073 - n2v_mse: 0.1073 - n2v_abs: 0.2590 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2851
# Epoch 205/500
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1081 - n2v_mse: 0.1081 - n2v_abs: 0.2593 - val_loss: 0.1336 - val_n2v_mse: 0.1336 - val_n2v_abs: 0.2849
# Epoch 206/500
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1108 - n2v_mse: 0.1108 - n2v_abs: 0.2613 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2852
# Epoch 207/500
# 8/8 [==============================] - 0s 47ms/step - loss: 0.1061 - n2v_mse: 0.1061 - n2v_abs: 0.2598 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 208/500
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1054 - n2v_mse: 0.1054 - n2v_abs: 0.2565 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 209/500
# 8/8 [==============================] - 1s 80ms/step - loss: 0.1127 - n2v_mse: 0.1127 - n2v_abs: 0.2633 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
#
# Epoch 00209: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 210/500
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1122 - n2v_mse: 0.1122 - n2v_abs: 0.2661 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2852
# Epoch 211/500
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1116 - n2v_mse: 0.1116 - n2v_abs: 0.2665 - val_loss: 0.1336 - val_n2v_mse: 0.1336 - val_n2v_abs: 0.2849
# Epoch 212/500
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1098 - n2v_mse: 0.1098 - n2v_abs: 0.2633 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 213/500
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1090 - n2v_mse: 0.1090 - n2v_abs: 0.2610 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2852
# Epoch 214/500
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1104 - n2v_mse: 0.1104 - n2v_abs: 0.2655 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2852
# Epoch 215/500
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1122 - n2v_mse: 0.1122 - n2v_abs: 0.2677 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2852
# Epoch 216/500
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1133 - n2v_mse: 0.1133 - n2v_abs: 0.2673 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2852
# Epoch 217/500
# 8/8 [==============================] - 0s 59ms/step - loss: 0.1094 - n2v_mse: 0.1094 - n2v_abs: 0.2616 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2852
# Epoch 218/500
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1175 - n2v_mse: 0.1175 - n2v_abs: 0.2709 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2852
# Epoch 219/500
# 8/8 [==============================] - 1s 86ms/step - loss: 0.1172 - n2v_mse: 0.1172 - n2v_abs: 0.2723 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2852
#
# Epoch 00219: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 220/500
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1120 - n2v_mse: 0.1120 - n2v_abs: 0.2650 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2852
# Epoch 221/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1096 - n2v_mse: 0.1096 - n2v_abs: 0.2634 - val_loss: 0.1336 - val_n2v_mse: 0.1336 - val_n2v_abs: 0.2849
# Epoch 222/500
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1045 - n2v_mse: 0.1045 - n2v_abs: 0.2565 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2853
# Epoch 223/500
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1100 - n2v_mse: 0.1100 - n2v_abs: 0.2628 - val_loss: 0.1339 - val_n2v_mse: 0.1339 - val_n2v_abs: 0.2853
# Epoch 224/500
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1084 - n2v_mse: 0.1084 - n2v_abs: 0.2617 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 225/500
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1197 - n2v_mse: 0.1197 - n2v_abs: 0.2764 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 226/500
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1142 - n2v_mse: 0.1142 - n2v_abs: 0.2667 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 227/500
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1159 - n2v_mse: 0.1159 - n2v_abs: 0.2677 - val_loss: 0.1336 - val_n2v_mse: 0.1336 - val_n2v_abs: 0.2849
# Epoch 228/500
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1064 - n2v_mse: 0.1064 - n2v_abs: 0.2594 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 229/500
# 8/8 [==============================] - 1s 79ms/step - loss: 0.1056 - n2v_mse: 0.1056 - n2v_abs: 0.2581 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
#
# Epoch 00229: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 230/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1159 - n2v_mse: 0.1159 - n2v_abs: 0.2685 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 231/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1101 - n2v_mse: 0.1101 - n2v_abs: 0.2602 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 232/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1125 - n2v_mse: 0.1125 - n2v_abs: 0.2641 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 233/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1155 - n2v_mse: 0.1155 - n2v_abs: 0.2704 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 234/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1096 - n2v_mse: 0.1096 - n2v_abs: 0.2611 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 235/500
# 8/8 [==============================] - 0s 46ms/step - loss: 0.1125 - n2v_mse: 0.1125 - n2v_abs: 0.2658 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 236/500
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1079 - n2v_mse: 0.1079 - n2v_abs: 0.2602 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 237/500
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1107 - n2v_mse: 0.1107 - n2v_abs: 0.2647 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 238/500
# 8/8 [==============================] - 1s 64ms/step - loss: 0.1054 - n2v_mse: 0.1054 - n2v_abs: 0.2580 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 239/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1144 - n2v_mse: 0.1144 - n2v_abs: 0.2694 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
#
# Epoch 00239: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# Epoch 240/500
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1097 - n2v_mse: 0.1097 - n2v_abs: 0.2633 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 241/500
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1136 - n2v_mse: 0.1136 - n2v_abs: 0.2674 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 242/500
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1098 - n2v_mse: 0.1098 - n2v_abs: 0.2629 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 243/500
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1111 - n2v_mse: 0.1111 - n2v_abs: 0.2633 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 244/500
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1139 - n2v_mse: 0.1139 - n2v_abs: 0.2669 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 245/500
# 8/8 [==============================] - 1s 85ms/step - loss: 0.1118 - n2v_mse: 0.1118 - n2v_abs: 0.2645 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 246/500
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1190 - n2v_mse: 0.1190 - n2v_abs: 0.2721 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 247/500
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1145 - n2v_mse: 0.1145 - n2v_abs: 0.2689 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 248/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1123 - n2v_mse: 0.1123 - n2v_abs: 0.2648 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 249/500
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1133 - n2v_mse: 0.1133 - n2v_abs: 0.2662 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
#
# Epoch 00249: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# Epoch 250/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1085 - n2v_mse: 0.1085 - n2v_abs: 0.2603 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 251/500
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1120 - n2v_mse: 0.1120 - n2v_abs: 0.2652 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 252/500
# 8/8 [==============================] - 0s 40ms/step - loss: 0.1091 - n2v_mse: 0.1091 - n2v_abs: 0.2620 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 253/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1130 - n2v_mse: 0.1130 - n2v_abs: 0.2673 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 254/500
# 8/8 [==============================] - 1s 76ms/step - loss: 0.1122 - n2v_mse: 0.1122 - n2v_abs: 0.2654 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 255/500
# ...
# Epoch 417/500
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1039 - n2v_mse: 0.1039 - n2v_abs: 0.2569 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 418/500
# 8/8 [==============================] - 0s 59ms/step - loss: 0.1102 - n2v_mse: 0.1102 - n2v_abs: 0.2608 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 419/500
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1115 - n2v_mse: 0.1115 - n2v_abs: 0.2631 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
#
# Epoch 00419: ReduceLROnPlateau reducing learning rate to 7.450580408706331e-13.
# Epoch 420/500
# 8/8 [==============================] - 1s 64ms/step - loss: 0.1096 - n2v_mse: 0.1096 - n2v_abs: 0.2612 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 421/500
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1099 - n2v_mse: 0.1099 - n2v_abs: 0.2652 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 422/500
# 8/8 [==============================] - 0s 59ms/step - loss: 0.1070 - n2v_mse: 0.1070 - n2v_abs: 0.2584 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 423/500
# 8/8 [==============================] - 0s 44ms/step - loss: 0.1117 - n2v_mse: 0.1117 - n2v_abs: 0.2647 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 424/500
# 8/8 [==============================] - 0s 42ms/step - loss: 0.1117 - n2v_mse: 0.1117 - n2v_abs: 0.2644 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 425/500
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1141 - n2v_mse: 0.1141 - n2v_abs: 0.2667 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 426/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1144 - n2v_mse: 0.1144 - n2v_abs: 0.2675 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 427/500
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1151 - n2v_mse: 0.1151 - n2v_abs: 0.2692 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 428/500
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1137 - n2v_mse: 0.1137 - n2v_abs: 0.2648 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 429/500
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1117 - n2v_mse: 0.1117 - n2v_abs: 0.2666 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
#
# Epoch 00429: ReduceLROnPlateau reducing learning rate to 3.7252902043531655e-13.
# Epoch 430/500
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1059 - n2v_mse: 0.1059 - n2v_abs: 0.2601 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 431/500
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1069 - n2v_mse: 0.1069 - n2v_abs: 0.2607 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 432/500
# 8/8 [==============================] - 0s 43ms/step - loss: 0.1123 - n2v_mse: 0.1123 - n2v_abs: 0.2671 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 433/500
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1089 - n2v_mse: 0.1089 - n2v_abs: 0.2617 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 434/500
# 8/8 [==============================] - 1s 79ms/step - loss: 0.1095 - n2v_mse: 0.1095 - n2v_abs: 0.2615 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 435/500
# 8/8 [==============================] - 1s 77ms/step - loss: 0.1119 - n2v_mse: 0.1119 - n2v_abs: 0.2648 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 436/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1141 - n2v_mse: 0.1141 - n2v_abs: 0.2655 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 437/500
# 8/8 [==============================] - 1s 64ms/step - loss: 0.1123 - n2v_mse: 0.1123 - n2v_abs: 0.2682 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 438/500
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1159 - n2v_mse: 0.1159 - n2v_abs: 0.2700 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 439/500
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1103 - n2v_mse: 0.1103 - n2v_abs: 0.2612 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
#
# Epoch 00439: ReduceLROnPlateau reducing learning rate to 1.8626451021765827e-13.
# Epoch 440/500
# 8/8 [==============================] - 0s 53ms/step - loss: 0.1096 - n2v_mse: 0.1096 - n2v_abs: 0.2623 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 441/500
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1092 - n2v_mse: 0.1092 - n2v_abs: 0.2608 - val_loss: 0.1337 - val_n2v_mse: 0.1337 - val_n2v_abs: 0.2849
# Epoch 442/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1124 - n2v_mse: 0.1124 - n2v_abs: 0.2657 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 443/500
# 8/8 [==============================] - 1s 73ms/step - loss: 0.1135 - n2v_mse: 0.1135 - n2v_abs: 0.2615 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 444/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1126 - n2v_mse: 0.1126 - n2v_abs: 0.2652 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 445/500
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1104 - n2v_mse: 0.1104 - n2v_abs: 0.2616 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 446/500
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1077 - n2v_mse: 0.1077 - n2v_abs: 0.2591 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 447/500
# 8/8 [==============================] - 0s 61ms/step - loss: 0.1075 - n2v_mse: 0.1075 - n2v_abs: 0.2603 - val_loss: 0.1337 - val_n2v_mse: 0.1337 - val_n2v_abs: 0.2849
# Epoch 448/500
# 8/8 [==============================] - 0s 55ms/step - loss: 0.1124 - n2v_mse: 0.1124 - n2v_abs: 0.2650 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 449/500
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1054 - n2v_mse: 0.1054 - n2v_abs: 0.2592 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
#
# Epoch 00449: ReduceLROnPlateau reducing learning rate to 9.313225510882914e-14.
# Epoch 450/500
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1106 - n2v_mse: 0.1106 - n2v_abs: 0.2657 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 451/500
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1103 - n2v_mse: 0.1103 - n2v_abs: 0.2655 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 452/500
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1035 - n2v_mse: 0.1035 - n2v_abs: 0.2568 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 453/500
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1035 - n2v_mse: 0.1035 - n2v_abs: 0.2556 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 454/500
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1047 - n2v_mse: 0.1047 - n2v_abs: 0.2583 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 455/500
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1110 - n2v_mse: 0.1110 - n2v_abs: 0.2650 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 456/500
# 8/8 [==============================] - 1s 65ms/step - loss: 0.1130 - n2v_mse: 0.1130 - n2v_abs: 0.2649 - val_loss: 0.1336 - val_n2v_mse: 0.1336 - val_n2v_abs: 0.2849
# Epoch 457/500
# 8/8 [==============================] - 0s 60ms/step - loss: 0.1148 - n2v_mse: 0.1148 - n2v_abs: 0.2696 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 458/500
# 8/8 [==============================] - 1s 64ms/step - loss: 0.1111 - n2v_mse: 0.1111 - n2v_abs: 0.2655 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 459/500
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1105 - n2v_mse: 0.1105 - n2v_abs: 0.2640 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
#
# Epoch 00459: ReduceLROnPlateau reducing learning rate to 4.656612755441457e-14.
# Epoch 460/500
# 8/8 [==============================] - 0s 59ms/step - loss: 0.1046 - n2v_mse: 0.1046 - n2v_abs: 0.2589 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 461/500
# 8/8 [==============================] - 1s 72ms/step - loss: 0.1044 - n2v_mse: 0.1044 - n2v_abs: 0.2578 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 462/500
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1091 - n2v_mse: 0.1091 - n2v_abs: 0.2626 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 463/500
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1061 - n2v_mse: 0.1061 - n2v_abs: 0.2595 - val_loss: 0.1336 - val_n2v_mse: 0.1336 - val_n2v_abs: 0.2849
# Epoch 464/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1061 - n2v_mse: 0.1061 - n2v_abs: 0.2608 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 465/500
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1102 - n2v_mse: 0.1102 - n2v_abs: 0.2609 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 466/500
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1092 - n2v_mse: 0.1092 - n2v_abs: 0.2610 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 467/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1131 - n2v_mse: 0.1131 - n2v_abs: 0.2651 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 468/500
# 8/8 [==============================] - 0s 48ms/step - loss: 0.1129 - n2v_mse: 0.1129 - n2v_abs: 0.2647 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 469/500
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1104 - n2v_mse: 0.1104 - n2v_abs: 0.2632 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
#
# Epoch 00469: ReduceLROnPlateau reducing learning rate to 2.3283063777207284e-14.
# Epoch 470/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1139 - n2v_mse: 0.1139 - n2v_abs: 0.2690 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 471/500
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1157 - n2v_mse: 0.1157 - n2v_abs: 0.2711 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 472/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1186 - n2v_mse: 0.1186 - n2v_abs: 0.2714 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 473/500
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1113 - n2v_mse: 0.1113 - n2v_abs: 0.2640 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 474/500
# 8/8 [==============================] - 0s 58ms/step - loss: 0.1114 - n2v_mse: 0.1114 - n2v_abs: 0.2642 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 475/500
# 8/8 [==============================] - 0s 57ms/step - loss: 0.1150 - n2v_mse: 0.1150 - n2v_abs: 0.2676 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 476/500
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1115 - n2v_mse: 0.1115 - n2v_abs: 0.2666 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
# Epoch 477/500
# 8/8 [==============================] - 0s 45ms/step - loss: 0.1158 - n2v_mse: 0.1158 - n2v_abs: 0.2719 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 478/500
# 8/8 [==============================] - 0s 56ms/step - loss: 0.1127 - n2v_mse: 0.1127 - n2v_abs: 0.2660 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 479/500
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1087 - n2v_mse: 0.1087 - n2v_abs: 0.2624 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
#
# Epoch 00479: ReduceLROnPlateau reducing learning rate to 1.1641531888603642e-14.
# Epoch 480/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1176 - n2v_mse: 0.1176 - n2v_abs: 0.2718 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 481/500
# 8/8 [==============================] - 0s 62ms/step - loss: 0.1160 - n2v_mse: 0.1160 - n2v_abs: 0.2717 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 482/500
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1118 - n2v_mse: 0.1118 - n2v_abs: 0.2651 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 483/500
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1121 - n2v_mse: 0.1121 - n2v_abs: 0.2651 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 484/500
# 8/8 [==============================] - 1s 69ms/step - loss: 0.1142 - n2v_mse: 0.1142 - n2v_abs: 0.2663 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 485/500
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1138 - n2v_mse: 0.1138 - n2v_abs: 0.2675 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 486/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1128 - n2v_mse: 0.1128 - n2v_abs: 0.2662 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 487/500
# 8/8 [==============================] - 0s 54ms/step - loss: 0.1089 - n2v_mse: 0.1089 - n2v_abs: 0.2628 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 488/500
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1114 - n2v_mse: 0.1114 - n2v_abs: 0.2655 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 489/500
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1102 - n2v_mse: 0.1102 - n2v_abs: 0.2647 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2853
#
# Epoch 00489: ReduceLROnPlateau reducing learning rate to 5.820765944301821e-15.
# Epoch 490/500
# 8/8 [==============================] - 1s 68ms/step - loss: 0.1139 - n2v_mse: 0.1139 - n2v_abs: 0.2667 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 491/500
# 8/8 [==============================] - 1s 70ms/step - loss: 0.1073 - n2v_mse: 0.1073 - n2v_abs: 0.2602 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 492/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1153 - n2v_mse: 0.1153 - n2v_abs: 0.2705 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 493/500
# 8/8 [==============================] - 1s 75ms/step - loss: 0.1109 - n2v_mse: 0.1109 - n2v_abs: 0.2626 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 494/500
# 8/8 [==============================] - 1s 63ms/step - loss: 0.1094 - n2v_mse: 0.1094 - n2v_abs: 0.2626 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 495/500
# 8/8 [==============================] - 0s 41ms/step - loss: 0.1161 - n2v_mse: 0.1161 - n2v_abs: 0.2701 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 496/500
# 8/8 [==============================] - 0s 49ms/step - loss: 0.1066 - n2v_mse: 0.1066 - n2v_abs: 0.2595 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 497/500
# 8/8 [==============================] - 1s 80ms/step - loss: 0.1131 - n2v_mse: 0.1131 - n2v_abs: 0.2664 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 498/500
# 8/8 [==============================] - 1s 66ms/step - loss: 0.1087 - n2v_mse: 0.1087 - n2v_abs: 0.2595 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
# Epoch 499/500
# 8/8 [==============================] - 1s 67ms/step - loss: 0.1132 - n2v_mse: 0.1132 - n2v_abs: 0.2683 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
#
# Epoch 00499: ReduceLROnPlateau reducing learning rate to 2.9103829721509105e-15.
# Epoch 500/500
# 8/8 [==============================] - 1s 71ms/step - loss: 0.1133 - n2v_mse: 0.1133 - n2v_abs: 0.2666 - val_loss: 0.1340 - val_n2v_mse: 0.1340 - val_n2v_abs: 0.2852
#
# Loading network weights from 'weights_best.h5'.

# %% [markdown]
# ### After training, lets plot training and validation loss.

# %%
print(sorted(list(history.history.keys())))
plt.figure(figsize=(16,5))
plot_history(history,['loss','val_loss']);
# Out:
# ['loss', 'lr', 'n2v_abs', 'n2v_mse', 'val_loss', 'val_n2v_abs', 'val_n2v_mse']

# %% [markdown]
# ## Export Model to be Used with CSBDeep Fiji Plugins and KNIME Workflows
# See https://github.com/CSBDeep/CSBDeep_website/wiki/Your-Model-in-Fiji for details.

# %%
model.export_TF()
# Out:
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/csbdeep/utils/tf.py:88: The name tf.saved_model.builder.SavedModelBuilder is deprecated. Please use tf.compat.v1.saved_model.builder.SavedModelBuilder instead.
#
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/csbdeep/utils/tf.py:89: The name tf.saved_model.signature_def_utils.predict_signature_def is deprecated. Please use tf.compat.v1.saved_model.signature_def_utils.predict_signature_def instead.
#
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/csbdeep/utils/tf.py:93: The name tf.saved_model.signature_constants.DEFAULT_SERVING_SIGNATURE_DEF_KEY is deprecated. Please use tf.saved_model.DEFAULT_SERVING_SIGNATURE_DEF_KEY instead.
#
# WARNING:tensorflow:From /home/qiang/anaconda3/envs/n2v/lib/python3.6/site-packages/csbdeep/utils/tf.py:95: The name tf.saved_model.tag_constants.SERVING is deprecated. Please use tf.saved_model.SERVING instead.
#
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /tmp/tmp8xrj2gba/model/saved_model.pb
#
# Model exported in TensorFlow's SavedModel format:
# /home/qiang/Documents/codefiles/low_level/denoise/n2v/examples/2D/denoising2D_RGB/models/n2v_2D/TF_SavedModel.zip
